# %% [markdown]
# The `paper_metadata.csv` file was downloaded from [here](https://static-content.springer.com/esm/art%3A10.1038%2Fs41467-019-10092-5/MediaObjects/41467_2019_10092_MOESM5_ESM.xlsx)
# It was converted to csv, the first two lines were removed and the values in Sequencing ID where used to fill the ENA accession column where it was missing
# The values in ENA accession of the Ashton Study were used to download the sequencing data with the downloading-tools workflow.
# The `reads_tables.csv` file was created by the downloading-tools workflow.
# The run ERR2624135 was not possible to download.

# %%
import pandas as pd
from Bio import Phylo

# %%
original = pd.read_csv('paper_metadata.csv', header = 0)

# %%
reads = pd.read_csv('reads_table.csv', header = 0)
reads = reads[['sample', 'run']]

# %% [markdown]
# Join the metadata and the read accessions to have a sample name and get the strain name from the Sequencing ID column

# %%
joined = pd.merge(original, reads, left_on = 'ENA accession', right_on = 'run', how = 'left')
joined = joined.drop(columns = ['run'])
joined = joined.rename(columns = {'Sequencing ID': 'strain', 'Isolation source': 'source', 'Sub-clade' : 'VNI_subdivision', 'Country of origin': 'Country_of_origin', 'ENA accession': 'SRA_Accession'})

# %% [markdown]
# Assign lineage from the colummn `Species ID from mash analysis`

# %%
joined.loc[joined['Species ID from mash anlaysis'] == 'Cryptococcus neoformans var. grubii H99', 'lineage'] = 'VNI'
joined.loc[joined['Species ID from mash anlaysis'] == 'Cryptococcus neoformans var. grubii H99/Cryptococcus neoformans var. neoformans JEC21 hybrid', 'lineage'] = 'AD_hybrid'
joined.loc[joined['Species ID from mash anlaysis'] == 'Cryptococcus gattii WM276', 'lineage'] = 'gattii'
joined.loc[joined['VNI_subdivision'] == 'VNII', 'lineage'] = 'VNII'
joined.loc[joined['VNI_subdivision'] == 'VNII', 'VNI_subdivision'] = None

# %% [markdown]
# Put the columns `sample`, `strain`, `lineage` and `VNI_subdivision` to the left of the rest and sort by VNI_subdivision

# %%
joined = joined[['sample', 'strain','lineage','source', 'VNI_subdivision'] + [col for col in joined.columns if col not in ['sample', 'strain','lineage','source','VNI_subdivision'] ]]
joined = joined.sort_values('VNI_subdivision')

# %% [markdown]
# Print number of samples in each lineage

# %%
for col in joined.select_dtypes(include='object').columns:
    joined[col] = joined[col].astype('category')
joined.groupby(['Study', 'lineage'], observed=True).size().reset_index(name='counts')
# Out:
#         Study    lineage  counts
# 0      Ashton  AD_hybrid       5
# 1      Ashton        VNI     678
# 2      Ashton       VNII       4
# 3      Ashton     gattii      12
# 4  Desjardins        VNI     185

# %% [markdown]
# Make file with metadata of all samples in Ashton paper

# %%
joined.to_csv('metadata_all_ashton_and_vni_desj.csv', index = False)

# %% [markdown]
# Filter out the Desjardins samples

# %%
ashton = joined[joined['Study'] != 'Desjardins']

# %% [markdown]
# Filter out the missing sample that was not downloaded

# %%
ashton = ashton[ashton['SRA_Accession'] != 'ERR2624135']

# %%
ashton
# Out:
#          sample       strain lineage    source VNI_subdivision       Lab ID  \
# 342   ERS542448   14936_1#57     VNI  Clinical         VNIa-32        BK167
# 245  ERS2540945  04CN-65-072     VNI  Clinical         VNIa-32  04CN-65-072
# 275  ERS2541049  04CN-65-161     VNI  Clinical         VNIa-32  04CN-65-161
# 150  ERS2541305  04CN-63-036     VNI  Clinical         VNIa-32  04CN-63-036
# 547  ERS1142749   20427_2#52     VNI  Clinical         VNIa-32         BK92
# ..          ...          ...     ...       ...             ...          ...
# 555  ERS2541337     BMD_1385  gattii  Clinical             NaN     BMD_1385
# 556  ERS2541338     BMD_1516  gattii  Clinical             NaN     BMD_1516
# 557  ERS2541339     BMD_2014  gattii  Clinical             NaN     BMD_2014
# 581  ERS2541082      BMD1964  gattii  Clinical             NaN      BMD1964
# 586  ERS2541145      BMD2233  gattii  Clinical             NaN      BMD2233
#
#                Species ID from mash anlaysis   Study HIV status SRA_Accession  \
# 342  Cryptococcus neoformans var. grubii H99  Ashton   positive     ERR842672
# 245  Cryptococcus neoformans var. grubii H99  Ashton   positive    ERR2624432
# 275  Cryptococcus neoformans var. grubii H99  Ashton   positive    ERR2624145
# 150  Cryptococcus neoformans var. grubii H99  Ashton   positive    ERR2624319
# 547  Cryptococcus neoformans var. grubii H99  Ashton   positive    ERR1671650
# ..                                       ...     ...        ...           ...
# 555                Cryptococcus gattii WM276  Ashton   negative    ERR2624309
# 556                Cryptococcus gattii WM276  Ashton   negative    ERR2624397
# 557                Cryptococcus gattii WM276  Ashton   negative    ERR2624500
# 581                Cryptococcus gattii WM276  Ashton   negative    ERR2624244
# 586                Cryptococcus gattii WM276  Ashton   negative    ERR2624259
#
#     Country_of_origin Continent of Origin  Year of Origin  \
# 342           Vietnam                Asia          2006.0
# 245            Uganda              Africa          2013.0
# 275            Uganda              Africa             NaN
# 150            Malawi              Africa          2014.0
# 547           Vietnam                Asia          2005.0
# ..                ...                 ...             ...
# 555           Vietnam                Asia          2007.0
# 556           Vietnam                Asia          2008.0
# 557           Vietnam                Asia             NaN
# 581           Vietnam                Asia          2009.0
# 586           Vietnam                Asia          2010.0
#
#      Mean depth of mapping with MQ > 30 across whole genome  \
# 342                                          31.391425
# 245                                          54.041513
# 275                                          45.413277
# 150                                          49.200974
# 547                                          38.213466
# ..                                                 ...
# 555                                          27.804298
# 556                                          25.317098
# 557                                          20.731607
# 581                                          35.464555
# 586                                          27.246364
#
#      Proportion of genome covered by at least 5 reads which mapped with MQ > 30
# 342                                           0.959204
# 245                                           0.990784
# 275                                           0.991486
# 150                                           0.987908
# 547                                           0.960260
# ..                                                 ...
# 555                                           0.608818
# 556                                           0.601971
# 557                                           0.587846
# 581                                           0.601434
# 586                                           0.600599
#
# [698 rows x 15 columns]

# %%
ashton.groupby(['Study', 'lineage'], observed=True).size().reset_index(name='counts')
# Out:
#     Study    lineage  counts
# 0  Ashton  AD_hybrid       5
# 1  Ashton        VNI     677
# 2  Ashton       VNII       4
# 3  Ashton     gattii      12

# %%
ashton.to_csv('metadata.csv', index = False, header = True)

# %% [markdown]
# Make file with non-VNI samples to exclude from the FungalPop analysis

# %%
exclude = ashton[ashton['lineage'] != 'VNI']
exclude = exclude.sort_values('lineage')
exclude.to_csv('metadata_ashton_non_vni.csv', index = False, header = True)
exclude['sample'].to_csv('exclude.txt', index = False, header = False)

# %% [markdown]
# ## Compare names in the Ashton phylogeny to metadata

# %%
tree = Phylo.read('/FastData/czirion/Crypto_Diversity_Pipeline/analyses/data/raw/2017.06.09.all_ours_and_desj.snp_sites.mod.fa.cln.tree', 'newick')
tips =[tip.name for tip in tree.get_terminals()]
print(len(tips))
tips_not_in_metadata = [tip for tip in tips if tip not in joined['strain'].values]
tips_not_in_metadata
# Out:
# 865
# ['GCF_000149245', '04CN-63-018']

# %%
strains_not_in_tree = joined[~joined['strain'].isin(tips)].reset_index(drop = True)
strains_not_in_tree
# Out:
#         sample           strain    lineage    source VNI_subdivision  \
# 0   ERS2541256      04CN-03-031  AD_hybrid  Clinical             NaN
# 1   ERS2541170      04CN-03-074       VNII  Clinical             NaN
# 2   ERS2541130      04CN-03-088       VNII  Clinical             NaN
# 3   ERS2540936      04CN-63-006     gattii  Clinical             NaN
# 4   ERS2540975      04CN-63-020     gattii  Clinical             NaN
# 5   ERS2541070      04CN-63-021     gattii  Clinical             NaN
# 6   ERS2541050      04CN-64-092  AD_hybrid  Clinical             NaN
# 7   ERS2541321      04CN-65-019  AD_hybrid  Clinical             NaN
# 8   ERS2541042      04CN-65-031       VNII  Clinical             NaN
# 9   ERS2541325      04CN-65-051     gattii  Clinical             NaN
# 10  ERS2540953      04CN-65-104     gattii  Clinical             NaN
# 11  ERS2540950      04CN-65-106       VNII  Clinical             NaN
# 12  ERS2540925      04CN-65-129  AD_hybrid  Clinical             NaN
# 13  ERS2540931      04CN-65-133  AD_hybrid  Clinical             NaN
# 14  ERS2541245  19CN-03-220-CSF     gattii  Clinical             NaN
# 15  ERS2541119  19CN-03-220-PAL     gattii  Clinical             NaN
# 16  ERS2541337         BMD_1385     gattii  Clinical             NaN
# 17  ERS2541338         BMD_1516     gattii  Clinical             NaN
# 18  ERS2541339         BMD_2014     gattii  Clinical             NaN
# 19  ERS2541082          BMD1964     gattii  Clinical             NaN
# 20  ERS2541145          BMD2233     gattii  Clinical             NaN
#
#              Lab ID                      Species ID from mash anlaysis  \
# 0       04CN-03-031  Cryptococcus neoformans var. grubii H99/Crypto...
# 1       04CN-03-074            Cryptococcus neoformans var. grubii H99
# 2       04CN-03-088            Cryptococcus neoformans var. grubii H99
# 3       04CN-63-006                          Cryptococcus gattii WM276
# 4       04CN-63-020                          Cryptococcus gattii WM276
# 5       04CN-63-021                          Cryptococcus gattii WM276
# 6       04CN-64-092  Cryptococcus neoformans var. grubii H99/Crypto...
# 7       04CN-65-019  Cryptococcus neoformans var. grubii H99/Crypto...
# 8       04CN-65-031            Cryptococcus neoformans var. grubii H99
# 9       04CN-65-051                          Cryptococcus gattii WM276
# 10      04CN-65-104                          Cryptococcus gattii WM276
# 11      04CN-65-106            Cryptococcus neoformans var. grubii H99
# 12      04CN-65-129  Cryptococcus neoformans var. grubii H99/Crypto...
# 13      04CN-65-133  Cryptococcus neoformans var. grubii H99/Crypto...
# 14  19CN-03-220-CSF                          Cryptococcus gattii WM276
# 15  19CN-03-220-PAL                          Cryptococcus gattii WM276
# 16         BMD_1385                          Cryptococcus gattii WM276
# 17         BMD_1516                          Cryptococcus gattii WM276
# 18         BMD_2014                          Cryptococcus gattii WM276
# 19          BMD1964                          Cryptococcus gattii WM276
# 20          BMD2233                          Cryptococcus gattii WM276
#
#      Study HIV status SRA_Accession Country_of_origin Continent of Origin  \
# 0   Ashton   positive    ERR2624093           Vietnam                Asia
# 1   Ashton   positive    ERR2624467           Vietnam                Asia
# 2   Ashton   positive    ERR2624180           Vietnam                Asia
# 3   Ashton   positive    ERR2624156            Uganda              Africa
# 4   Ashton   positive    ERR2624413            Uganda              Africa
# 5   Ashton   positive    ERR2624263            Uganda              Africa
# 6   Ashton   positive    ERR2624285            Uganda              Africa
# 7   Ashton   positive    ERR2624434            Uganda              Africa
# 8   Ashton   positive    ERR2624151            Uganda              Africa
# 9   Ashton   positive    ERR2624462            Uganda              Africa
# 10  Ashton   positive    ERR2624451            Uganda              Africa
# 11  Ashton   positive    ERR2624139            Uganda              Africa
# 12  Ashton   positive    ERR2624242            Uganda              Africa
# 13  Ashton   positive    ERR2624415            Uganda              Africa
# 14  Ashton   negative    ERR2624247           Vietnam                Asia
# 15  Ashton   negative    ERR2624419           Vietnam                Asia
# 16  Ashton   negative    ERR2624309           Vietnam                Asia
# 17  Ashton   negative    ERR2624397           Vietnam                Asia
# 18  Ashton   negative    ERR2624500           Vietnam                Asia
# 19  Ashton   negative    ERR2624244           Vietnam                Asia
# 20  Ashton   negative    ERR2624259           Vietnam                Asia
#
#     Year of Origin  Mean depth of mapping with MQ > 30 across whole genome  \
# 0           2013.0                                          45.693733
# 1           2014.0                                          43.472265
# 2           2014.0                                          45.057615
# 3           2014.0                                          30.811483
# 4           2014.0                                          31.976266
# 5           2014.0                                          30.489235
# 6           2014.0                                          32.871236
# 7           2013.0                                          78.893862
# 8           2013.0                                          31.248864
# 9           2013.0                                          44.914011
# 10          2014.0                                          18.444734
# 11             NaN                                          43.274274
# 12          2014.0                                          32.821441
# 13          2014.0                                          44.428216
# 14             NaN                                          22.227538
# 15             NaN                                          26.170335
# 16          2007.0                                          27.804298
# 17          2008.0                                          25.317098
# 18             NaN                                          20.731607
# 19          2009.0                                          35.464555
# 20          2010.0                                          27.246364
#
#     Proportion of genome covered by at least 5 reads which mapped with MQ > 30
# 0                                            0.975470
# 1                                            0.965882
# 2                                            0.966880
# 3                                            0.611245
# 4                                            0.604924
# 5                                            0.602266
# 6                                            0.969852
# 7                                            0.978027
# 8                                            0.963734
# 9                                            0.616338
# 10                                           0.596167
# 11                                           0.965697
# 12                                           0.974894
# 13                                           0.982900
# 14                                           0.591819
# 15                                           0.596044
# 16                                           0.608818
# 17                                           0.601971
# 18                                           0.587846
# 19                                           0.601434
# 20                                           0.600599
